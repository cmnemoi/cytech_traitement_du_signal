# %%
from app.data import load_mnist
from app.handwritten_digit_classifier import HandwrittenDigitClassifier
from matplotlib import pyplot as plt
import numpy as np

# %%
(X_train, X_test), (y_train, y_test) = load_mnist()

# %%
model = HandwrittenDigitClassifier()

# %%
plt.imshow(X_train[0], cmap='gray')

# %%
def fourier_transform(image):
    f = np.fft.fft2(image) # Compute the 2D Fourier transform
    fshift = np.fft.fftshift(f) # Shift the zero-frequency component to the center of the spectrum
    magnitude_spectrum = np.log(np.abs(fshift)) # Compute the magnitude spectrum and take the logarithm for visualization
    
    return magnitude_spectrum

# %%
X_test[0]
# Out:
# 5

# %%
N = 20
for i in range(N):
    plt.subplot(int(N/5), 5, i+1)
    plt.imshow(fourier_transform(X_train[i]))
    plt.text(14, 0, X_test[i], color='black', size=25)

# %%
X_test[0]
# Out:
# 5

# %%
model.predict(X_test[:1])
# Out:
# array([3])
